# %%
import main
main.plotHistExtroversion()
# Out:
# 49
# 12
# 29

# %%
import main
main.plotPieGrossExtroversion()

# %%
import main
main.plotPiePatternExtroversion()
# Out:
# ShapiroResult(statistic=0.9870374798774719, pvalue=0.35183754563331604)

# %%
import main
main.plotBoxOcean()

# %%
import main
main.plotPilotExpertise()

# %%
import main
main.plotPairProgrammingExpertise()

# %%
import main
main.plotCodeReviewExpertise()

# %%
import main
main.demographicData()
# Out:
# -----All:
# Age < 20 3# 2.65%
# Age 20-29 70# 61.95%
# Age 30-39 31# 27.43%
# Age > 40 9# 7.96%
# -
# Male 81# 71.68%
# Female 30# 26.55%
# Não Binário 1# 0.88%
# Prefiro não informar 1# 0.88%
# -
# br 106# 93.81%
# outro 7# 6.19%
# -
# bachareladoI 44# 38.94%
# bachareladoC 32# 28.32%
# mestradoI 10# 8.85%
# mestradoC 10# 8.85%
# doutoradoI 7# 6.19%
# doutoradoC 4# 3.54%
# Outro 6# 5.31%
# -
# cic 70# 61.95%
# ecp 10# 8.85%
# si 8# 7.08%
# es 6# 5.31%
# ads 5# 4.42%
# jd 3# 2.65%
# Outro 11# 9.73%
# -
# 2 years 15# 13.27%
# 2-5 45# 39.82%
# 5-10 24# 21.24%
# > 10 29# 25.66%
# -
# veryLow 1# 0.88%
# low 2# 1.77%
# medium 40# 35.40%
# high 45# 39.82%
# veryHigh 25# 22.12%
# -----Intro:
# Age < 20 0# 0.00%
# Age 20-29 16# 72.73%
# Age 30-39 6# 27.27%
# Age > 40 0# 0.00%
# -
# Male 16# 72.73%
# Female 6# 27.27%
# Não Binário 0# 0.00%
# Prefiro não informar 0# 0.00%
# -
# br 21# 95.45%
# outro 1# 4.55%
# -
# bachareladoI 12# 54.55%
# bachareladoC 5# 22.73%
# mestradoI 0# 0.00%
# ...
